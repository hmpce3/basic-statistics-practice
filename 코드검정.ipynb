# %%
from hossam import diff, make_api_docs
# Out:
# 📦 아이티윌 이광호 강사가 제작한 라이브러리를 사용중입니다.
# 📚 자세한 사용 방법은 https://py.hossam.kr 을 참고하세요.
# 📧 Email: leekh4232@gmail.com
# 🎬 Youtube: https://www.youtube.com/@hossam-codingclub
# 📝 Blog: https://blog.hossam.kr/
# 🔖 Version: 0.5.29

# %% [markdown]
# ## #01. 내 helper의 메뉴얼 만들기
# - 첫 번째 파라미터 : 내 helper의 경로
# - 두 번째 파라미터 : 메뉴얼이 생성될 경로(폴더)
#
# 두 번째 파라미터는 미리 존재하지 않더라도 문제 없음
# 문서가 생성되면 생성 폴더 안의 index.html 파일을 더블클릭 하세요

# %%
make_api_docs("./helpers", "./docs/helpers")
# Out:
# [준비] 모듈 6개: my_logit, my_ols, my_plot, my_prep, my_qtcheck, my_stats
# [빌드] 문서를 생성하는 중입니다...
# [완료] 문서가 생성되었습니다: C:\Users\itwill\Desktop\이하은\my work\통계\기초통계\docs\helpers
#        C:\Users\itwill\Desktop\이하은\my work\통계\기초통계\docs\helpers\index.html 파일을 브라우저로 열어보세요.
# <a href="file:///C:/Users/itwill/Desktop/%EC%9D%B4%ED%95%98%EC%9D%80/my%20work/%ED%86%B5%EA%B3%84/%EA%B8%B0%EC%B4%88%ED%86%B5%EA%B3%84/docs/helpers/index.html" target="_blank">📄 생성된 API 문서 열기 (index.html)</a>
# 'C:\\Users\\itwill\\Desktop\\이하은\\my work\\통계\\기초통계\\docs\\helpers\\index.html'

# %%
diff("my_logit", "helpers/my_logit.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("__init__", "helpers/__init__.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_ols", "helpers/my_ols.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_plot", "helpers/my_plot.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_prep", "helpers/my_prep.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_qtcheck", "helpers/my_qtcheck.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_stats", "helpers/my_stats.py")
# Out:
#  |          | 0/4
# ...
